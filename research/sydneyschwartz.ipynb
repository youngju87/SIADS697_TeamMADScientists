# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
from sklearn import preprocessing

# %%
# info on dataset from https://www.detroitk12.org/Page/9634

# Student assessment in grades 3 through 8 includes the Michigan Student Test of Educational Progress (M-STEP), a summative assessment based on Michigan’s content standards, designed to measure achievement and growth effectively for most students.

# Students are tested in all grades from 3 through 8 in Math and English language arts (ELA), grades 4 and 7 in Science, and grades 5 and 8 in Social Studies. For M-STEP, 11th grade students are tested in Science, and Social Studies. For MI-Access, 11th grade students are tested in ELA, Mathematics, Science, and Social Studies.

# MI-Access tests come in three varieties: Functional Independence (FI), Supported Independence (SI), and Participation (P). More information about the MI-Access test and test accommodations for students can be found at the MI-Access website.

# You can explore the M-STEP report by entity (school, district, intermediate school district, and statewide), by subject (ELA, math, science, or social studies), and by different demographic factors such as gender, ethnicity, and socioeconomic status.

# The M-STEP report shows student performance, scaled score, and proficiency in ELA, math, science, and social studies.

#Isd stands for intermediate school district

# %%
#list of application schools in the district from https://www.detroitk12.org/Page/15142

# What are the K-12 application schools for the 2022-23 school year? 

# K-8 Application Schools 

# Academy of the Americas (K-8) 
# Bates Academy (K-8) 
# Clippert Multicultural Honors Academy (6-8) 
# Chrysler Elementary (K-5) 
# Detroit International Academy (K-8) 
# Foreign Language Immersion and Cultural Studies School (FLICS) (K-8) 
# Golightly Education Center (K-8) 
# Marcus Garvey Academy (K-8) 
# Paul Robeson/ Malcolm X Academy (K-8) 
# The School at Marygrove (K-2)

# High School Application Schools 

# Academy of the Americas 
# Benjamin Carson High School of Science and Medicine 
# Davis Aerospace Technical High School 
# Detroit International Academy for Young Women 
# Detroit School of Arts 
# Frederick Douglass Academy for Young Men

# %%
#import testing data
test = pd.read_csv('/work/SIADS697_TeamMADScientists/assets/testing_data/DPSCD_OpenData_MSTEP_Growth_2018-2019_20191101.csv')
test_count = test['BuildingName'].unique()

#dataset contains 95 of the 107 schools in the Detroit Public Schools Community District

# %%
#import zip code data
zip_code = pd.read_csv('/work/SIADS697_TeamMADScientists/assets/testing_data/DPSCD_School_List_2018-2019_20190226.csv')
zip_count = zip_code['BuildingName'].unique()

# %%
#finding the columns that the two datasets have in common so no info is repeated. 

same_name = []

for col in zip_code.columns:
    for cols in test.columns:
        if col == cols:
            same_name.append(col)

print(same_name)
# Out:
# ['SchoolYear', 'BuildingCode', 'BuildingName', 'DistrictCode', 'DistrictName', 'EntityType']

# %%
#dropping all duplicate columns except BuildingName which we will merge with
zip_code = zip_code.drop(['SchoolYear', 'BuildingCode', 'DistrictCode', 'DistrictName', 'EntityType', 'COUNTY_NAME', 'LOCALE_NAME', 'SCHOOL_LEVEL', 'SCHOOL_TYPE', 'SETTING'], axis = 1)
test = test.drop(['IsdCode','IsdName'], axis = 1)

# %%
# merging the data sets
df_test = test.merge(zip_code, how='inner', on='BuildingName')
df_test.head()
# Out:
#   SchoolYear  DistrictCode                               DistrictName  \
# 0  2018-2019         82015  Detroit Public Schools Community District
# 1  2018-2019         82015  Detroit Public Schools Community District
# 2  2018-2019         82015  Detroit Public Schools Community District
# 3  2018-2019         82015  Detroit Public Schools Community District
# 4  2018-2019         82015  Detroit Public Schools Community District
#
#    BuildingCode       BuildingName  CountyCode CountyName  EntityType  \
# 0             4  Henderson Academy          82      Wayne  LEA School
# 1             4  Henderson Academy          82      Wayne  LEA School
# 2             4  Henderson Academy          82      Wayne  LEA School
# 3             4  Henderson Academy          82      Wayne  LEA School
# 4             4  Henderson Academy          82      Wayne  LEA School
#
#           SchoolLevel       Locale  ... MeanSGP ISDCode     ISDName  \
# 0  Elem_Middle School  City: Large  ...    < 10      82  Wayne RESA
# 1  Elem_Middle School  City: Large  ...    < 10      82  Wayne RESA
# 2  Elem_Middle School  City: Large  ...   25.80      82  Wayne RESA
# 3  Elem_Middle School  City: Large  ...   25.80      82  Wayne RESA
# 4  Elem_Middle School  City: Large  ...   25.60      82  Wayne RESA
#
#         Status    SCHOOL_EMPHASIS PhoneNumber         ADDRESS_LINE_1     CITY  \
# 0  Open-Active  General Education  3138520512  16101 West Chicago St  Detroit
# 1  Open-Active  General Education  3138520512  16101 West Chicago St  Detroit
# 2  Open-Active  General Education  3138520512  16101 West Chicago St  Detroit
# 3  Open-Active  General Education  3138520512  16101 West Chicago St  Detroit
# 4  Open-Active  General Education  3138520512  16101 West Chicago St  Detroit
#
#   STATE ZIP_CODE
# 0    MI    48228
# 1    MI    48228
# 2    MI    48228
# 3    MI    48228
# 4    MI    48228
#
# [5 rows x 30 columns]

# %%
#There are no missing values in the dataframe
df_test.isnull().values.any()
# Out:
# False

# %%
#exploring data, looking at how many schools have reported precentages and numbers and how much data there is for testing groups. 
df_test_eco_dis = df_test.loc[(df_test['TestingGroup'] == 'Economically Disadvantaged') & (df_test['Subject']  == 'Mathematics') & (df_test['Grade'] == 'All Grades')]

# %%
_deepnote_run_altair(df_test_eco_dis, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"bar","tooltip":true},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"BuildingName","type":"nominal","sort":{"order":"descending","encoding":"y"},"scale":{"type":"linear","zero":false}},"y":{"field":"PercentAboveAverage","type":"quantitative","sort":null,"scale":{"type":"linear","zero":true}},"color":{"field":"ZIP_CODE","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %%
# checking to see why West Side did not show a bar on the graph
# its because it the value has a < symbol
df_west = df_test[df_test['BuildingName'].str.contains('West Side')]
df_west
# Out:
#       SchoolYear  DistrictCode                               DistrictName  \
# 11049  2018-2019         82015  Detroit Public Schools Community District
# 11050  2018-2019         82015  Detroit Public Schools Community District
# 11051  2018-2019         82015  Detroit Public Schools Community District
# 11052  2018-2019         82015  Detroit Public Schools Community District
# 11053  2018-2019         82015  Detroit Public Schools Community District
# 11054  2018-2019         82015  Detroit Public Schools Community District
# 11055  2018-2019         82015  Detroit Public Schools Community District
# 11056  2018-2019         82015  Detroit Public Schools Community District
# 11057  2018-2019         82015  Detroit Public Schools Community District
# 11058  2018-2019         82015  Detroit Public Schools Community District
# 11059  2018-2019         82015  Detroit Public Schools Community District
# 11060  2018-2019         82015  Detroit Public Schools Community District
# 11061  2018-2019         82015  Detroit Public Schools Community District
# 11062  2018-2019         82015  Detroit Public Schools Community District
# 11063  2018-2019         82015  Detroit Public Schools Community District
# 11064  2018-2019         82015  Detroit Public Schools Community District
# 11065  2018-2019         82015  Detroit Public Schools Community District
# 11066  2018-2019         82015  Detroit Public Schools Community District
# 11067  2018-2019         82015  Detroit Public Schools Community District
# 11068  2018-2019         82015  Detroit Public Schools Community District
# 11069  2018-2019         82015  Detroit Public Schools Community District
# 11070  2018-2019         82015  Detroit Public Schools Community District
# 11071  2018-2019         82015  Detroit Public Schools Community District
# 11072  2018-2019         82015  Detroit Public Schools Community District
# 11073  2018-2019         82015  Detroit Public Schools Community District
# 11074  2018-2019         82015  Detroit Public Schools Community District
# 11075  2018-2019         82015  Detroit Public Schools Community District
# 11076  2018-2019         82015  Detroit Public Schools Community District
# 11077  2018-2019         82015  Detroit Public Schools Community District
# 11078  2018-2019         82015  Detroit Public Schools Community District
# 11079  2018-2019         82015  Detroit Public Schools Community District
# 11080  2018-2019         82015  Detroit Public Schools Community District
# 11081  2018-2019         82015  Detroit Public Schools Community District
# 11082  2018-2019         82015  Detroit Public Schools Community District
# 11083  2018-2019         82015  Detroit Public Schools Community District
# 11084  2018-2019         82015  Detroit Public Schools Community District
# 11085  2018-2019         82015  Detroit Public Schools Community District
# 11086  2018-2019         82015  Detroit Public Schools Community District
# 11087  2018-2019         82015  Detroit Public Schools Community District
# 11088  2018-2019         82015  Detroit Public Schools Community District
# 11089  2018-2019         82015  Detroit Public Schools Community District
# 11090  2018-2019         82015  Detroit Public Schools Community District
# 11091  2018-2019         82015  Detroit Public Schools Community District
# 11092  2018-2019         82015  Detroit Public Schools Community District
# 11093  2018-2019         82015  Detroit Public Schools Community District
# 11094  2018-2019         82015  Detroit Public Schools Community District
# 11095  2018-2019         82015  Detroit Public Schools Community District
# 11096  2018-2019         82015  Detroit Public Schools Community District
# 11097  2018-2019         82015  Detroit Public Schools Community District
# 11098  2018-2019         82015  Detroit Public Schools Community District
# 11099  2018-2019         82015  Detroit Public Schools Community District
# 11100  2018-2019         82015  Detroit Public Schools Community District
# 11101  2018-2019         82015  Detroit Public Schools Community District
# 11102  2018-2019         82015  Detroit Public Schools Community District
# 11103  2018-2019         82015  Detroit Public Schools Community District
# 11104  2018-2019         82015  Detroit Public Schools Community District
# 11105  2018-2019         82015  Detroit Public Schools Community District
# 11106  2018-2019         82015  Detroit Public Schools Community District
# 11107  2018-2019         82015  Detroit Public Schools Community District
# 11108  2018-2019         82015  Detroit Public Schools Community District
#
#        BuildingCode                                       BuildingName  \
# 11049          8929  West Side Academy of Information Technology an...
# 11050          8929  West Side Academy of Information Technology an...
# 11051          8929  West Side Academy of Information Technology an...
# 11052          8929  West Side Academy of Information Technology an...
# 11053          8929  West Side Academy of Information Technology an...
# 11054          8929  West Side Academy of Information Technology an...
# 11055          8929  West Side Academy of Information Technology an...
# 11056          8929  West Side Academy of Information Technology an...
# 11057          8929  West Side Academy of Information Technology an...
# 11058          8929  West Side Academy of Information Technology an...
# 11059          8929  West Side Academy of Information Technology an...
# 11060          8929  West Side Academy of Information Technology an...
# 11061          8929  West Side Academy of Information Technology an...
# 11062          8929  West Side Academy of Information Technology an...
# 11063          8929  West Side Academy of Information Technology an...
# 11064          8929  West Side Academy of Information Technology an...
# 11065          8929  West Side Academy of Information Technology an...
# 11066          8929  West Side Academy of Information Technology an...
# 11067          8929  West Side Academy of Information Technology an...
# 11068          8929  West Side Academy of Information Technology an...
# 11069          8929  West Side Academy of Information Technology an...
# 11070          8929  West Side Academy of Information Technology an...
# 11071          8929  West Side Academy of Information Technology an...
# 11072          8929  West Side Academy of Information Technology an...
# 11073          8929  West Side Academy of Information Technology an...
# 11074          8929  West Side Academy of Information Technology an...
# 11075          8929  West Side Academy of Information Technology an...
# 11076          8929  West Side Academy of Information Technology an...
# 11077          8929  West Side Academy of Information Technology an...
# 11078          8929  West Side Academy of Information Technology an...
# 11079          8929  West Side Academy of Information Technology an...
# 11080          8929  West Side Academy of Information Technology an...
# 11081          8929  West Side Academy of Information Technology an...
# 11082          8929  West Side Academy of Information Technology an...
# 11083          8929  West Side Academy of Information Technology an...
# 11084          8929  West Side Academy of Information Technology an...
# 11085          8929  West Side Academy of Information Technology an...
# 11086          8929  West Side Academy of Information Technology an...
# 11087          8929  West Side Academy of Information Technology an...
# 11088          8929  West Side Academy of Information Technology an...
# 11089          8929  West Side Academy of Information Technology an...
# 11090          8929  West Side Academy of Information Technology an...
# 11091          8929  West Side Academy of Information Technology an...
# 11092          8929  West Side Academy of Information Technology an...
# 11093          8929  West Side Academy of Information Technology an...
# 11094          8929  West Side Academy of Information Technology an...
# 11095          8929  West Side Academy of Information Technology an...
# 11096          8929  West Side Academy of Information Technology an...
# 11097          8929  West Side Academy of Information Technology an...
# 11098          8929  West Side Academy of Information Technology an...
# 11099          8929  West Side Academy of Information Technology an...
# 11100          8929  West Side Academy of Information Technology an...
# 11101          8929  West Side Academy of Information Technology an...
# 11102          8929  West Side Academy of Information Technology an...
# 11103          8929  West Side Academy of Information Technology an...
# 11104          8929  West Side Academy of Information Technology an...
# 11105          8929  West Side Academy of Information Technology an...
# 11106          8929  West Side Academy of Information Technology an...
# 11107          8929  West Side Academy of Information Technology an...
# 11108          8929  West Side Academy of Information Technology an...
#
#        CountyCode CountyName  EntityType  SchoolLevel       Locale  ...  \
# 11049          82      Wayne  LEA School  High School  City: Large  ...
# 11050          82      Wayne  LEA School  High School  City: Large  ...
# 11051          82      Wayne  LEA School  High School  City: Large  ...
# 11052          82      Wayne  LEA School  High School  City: Large  ...
# 11053          82      Wayne  LEA School  High School  City: Large  ...
# 11054          82      Wayne  LEA School  High School  City: Large  ...
# 11055          82      Wayne  LEA School  High School  City: Large  ...
# 11056          82      Wayne  LEA School  High School  City: Large  ...
# 11057          82      Wayne  LEA School  High School  City: Large  ...
# 11058          82      Wayne  LEA School  High School  City: Large  ...
# 11059          82      Wayne  LEA School  High School  City: Large  ...
# 11060          82      Wayne  LEA School  High School  City: Large  ...
# 11061          82      Wayne  LEA School  High School  City: Large  ...
# 11062          82      Wayne  LEA School  High School  City: Large  ...
# 11063          82      Wayne  LEA School  High School  City: Large  ...
# 11064          82      Wayne  LEA School  High School  City: Large  ...
# 11065          82      Wayne  LEA School  High School  City: Large  ...
# 11066          82      Wayne  LEA School  High School  City: Large  ...
# 11067          82      Wayne  LEA School  High School  City: Large  ...
# 11068          82      Wayne  LEA School  High School  City: Large  ...
# 11069          82      Wayne  LEA School  High School  City: Large  ...
# 11070          82      Wayne  LEA School  High School  City: Large  ...
# 11071          82      Wayne  LEA School  High School  City: Large  ...
# 11072          82      Wayne  LEA School  High School  City: Large  ...
# 11073          82      Wayne  LEA School  High School  City: Large  ...
# 11074          82      Wayne  LEA School  High School  City: Large  ...
# 11075          82      Wayne  LEA School  High School  City: Large  ...
# 11076          82      Wayne  LEA School  High School  City: Large  ...
# 11077          82      Wayne  LEA School  High School  City: Large  ...
# 11078          82      Wayne  LEA School  High School  City: Large  ...
# 11079          82      Wayne  LEA School  High School  City: Large  ...
# 11080          82      Wayne  LEA School  High School  City: Large  ...
# 11081          82      Wayne  LEA School  High School  City: Large  ...
# 11082          82      Wayne  LEA School  High School  City: Large  ...
# 11083          82      Wayne  LEA School  High School  City: Large  ...
# 11084          82      Wayne  LEA School  High School  City: Large  ...
# 11085          82      Wayne  LEA School  High School  City: Large  ...
# 11086          82      Wayne  LEA School  High School  City: Large  ...
# 11087          82      Wayne  LEA School  High School  City: Large  ...
# 11088          82      Wayne  LEA School  High School  City: Large  ...
# 11089          82      Wayne  LEA School  High School  City: Large  ...
# 11090          82      Wayne  LEA School  High School  City: Large  ...
# 11091          82      Wayne  LEA School  High School  City: Large  ...
# 11092          82      Wayne  LEA School  High School  City: Large  ...
# 11093          82      Wayne  LEA School  High School  City: Large  ...
# 11094          82      Wayne  LEA School  High School  City: Large  ...
# 11095          82      Wayne  LEA School  High School  City: Large  ...
# 11096          82      Wayne  LEA School  High School  City: Large  ...
# 11097          82      Wayne  LEA School  High School  City: Large  ...
# 11098          82      Wayne  LEA School  High School  City: Large  ...
# 11099          82      Wayne  LEA School  High School  City: Large  ...
# 11100          82      Wayne  LEA School  High School  City: Large  ...
# 11101          82      Wayne  LEA School  High School  City: Large  ...
# 11102          82      Wayne  LEA School  High School  City: Large  ...
# 11103          82      Wayne  LEA School  High School  City: Large  ...
# 11104          82      Wayne  LEA School  High School  City: Large  ...
# 11105          82      Wayne  LEA School  High School  City: Large  ...
# 11106          82      Wayne  LEA School  High School  City: Large  ...
# 11107          82      Wayne  LEA School  High School  City: Large  ...
# 11108          82      Wayne  LEA School  High School  City: Large  ...
#
#       MeanSGP ISDCode     ISDName       Status        SCHOOL_EMPHASIS  \
# 11049    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11050    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11051    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11052    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11053    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11054    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11055    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11056    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11057    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11058    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11059    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11060    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11061    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11062    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11063    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11064    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11065    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11066    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11067    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11068    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11069    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11070    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11071    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11072    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11073    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11074    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11075    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11076    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11077    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11078    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11079    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11080    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11081    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11082    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11083    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11084    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11085    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11086    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11087    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11088    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11089    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11090    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11091    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11092    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11093    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11094    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11095    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11096    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11097    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11098    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11099    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11100    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11101    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11102    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11103    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11104    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11105    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11106    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11107    < 10      82  Wayne RESA  Open-Active  Alternative Education
# 11108    < 10      82  Wayne RESA  Open-Active  Alternative Education
#
#       PhoneNumber ADDRESS_LINE_1     CITY STATE ZIP_CODE
# 11049  3135960775  4701 Mckinley  Detroit    MI    48208
# 11050  3135960775  4701 Mckinley  Detroit    MI    48208
# 11051  3135960775  4701 Mckinley  Detroit    MI    48208
# 11052  3135960775  4701 Mckinley  Detroit    MI    48208
# 11053  3135960775  4701 Mckinley  Detroit    MI    48208
# 11054  3135960775  4701 Mckinley  Detroit    MI    48208
# 11055  3135960775  4701 Mckinley  Detroit    MI    48208
# 11056  3135960775  4701 Mckinley  Detroit    MI    48208
# 11057  3135960775  4701 Mckinley  Detroit    MI    48208
# 11058  3135960775  4701 Mckinley  Detroit    MI    48208
# 11059  3135960775  4701 Mckinley  Detroit    MI    48208
# 11060  3135960775  4701 Mckinley  Detroit    MI    48208
# 11061  3135960775  4701 Mckinley  Detroit    MI    48208
# 11062  3135960775  4701 Mckinley  Detroit    MI    48208
# 11063  3135960775  4701 Mckinley  Detroit    MI    48208
# 11064  3135960775  4701 Mckinley  Detroit    MI    48208
# 11065  3135960775  4701 Mckinley  Detroit    MI    48208
# 11066  3135960775  4701 Mckinley  Detroit    MI    48208
# 11067  3135960775  4701 Mckinley  Detroit    MI    48208
# 11068  3135960775  4701 Mckinley  Detroit    MI    48208
# 11069  3135960775  4701 Mckinley  Detroit    MI    48208
# 11070  3135960775  4701 Mckinley  Detroit    MI    48208
# 11071  3135960775  4701 Mckinley  Detroit    MI    48208
# 11072  3135960775  4701 Mckinley  Detroit    MI    48208
# 11073  3135960775  4701 Mckinley  Detroit    MI    48208
# 11074  3135960775  4701 Mckinley  Detroit    MI    48208
# 11075  3135960775  4701 Mckinley  Detroit    MI    48208
# 11076  3135960775  4701 Mckinley  Detroit    MI    48208
# 11077  3135960775  4701 Mckinley  Detroit    MI    48208
# 11078  3135960775  4701 Mckinley  Detroit    MI    48208
# 11079  3135960775  4701 Mckinley  Detroit    MI    48208
# 11080  3135960775  4701 Mckinley  Detroit    MI    48208
# 11081  3135960775  4701 Mckinley  Detroit    MI    48208
# 11082  3135960775  4701 Mckinley  Detroit    MI    48208
# 11083  3135960775  4701 Mckinley  Detroit    MI    48208
# 11084  3135960775  4701 Mckinley  Detroit    MI    48208
# 11085  3135960775  4701 Mckinley  Detroit    MI    48208
# 11086  3135960775  4701 Mckinley  Detroit    MI    48208
# 11087  3135960775  4701 Mckinley  Detroit    MI    48208
# 11088  3135960775  4701 Mckinley  Detroit    MI    48208
# 11089  3135960775  4701 Mckinley  Detroit    MI    48208
# 11090  3135960775  4701 Mckinley  Detroit    MI    48208
# 11091  3135960775  4701 Mckinley  Detroit    MI    48208
# 11092  3135960775  4701 Mckinley  Detroit    MI    48208
# 11093  3135960775  4701 Mckinley  Detroit    MI    48208
# 11094  3135960775  4701 Mckinley  Detroit    MI    48208
# 11095  3135960775  4701 Mckinley  Detroit    MI    48208
# 11096  3135960775  4701 Mckinley  Detroit    MI    48208
# 11097  3135960775  4701 Mckinley  Detroit    MI    48208
# 11098  3135960775  4701 Mckinley  Detroit    MI    48208
# 11099  3135960775  4701 Mckinley  Detroit    MI    48208
# 11100  3135960775  4701 Mckinley  Detroit    MI    48208
# 11101  3135960775  4701 Mckinley  Detroit    MI    48208
# 11102  3135960775  4701 Mckinley  Detroit    MI    48208
# 11103  3135960775  4701 Mckinley  Detroit    MI    48208
# 11104  3135960775  4701 Mckinley  Detroit    MI    48208
# 11105  3135960775  4701 Mckinley  Detroit    MI    48208
# 11106  3135960775  4701 Mckinley  Detroit    MI    48208
# 11107  3135960775  4701 Mckinley  Detroit    MI    48208
# 11108  3135960775  4701 Mckinley  Detroit    MI    48208
#
# [60 rows x 30 columns]

# %%
_deepnote_run_altair(df_test_eco_dis, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"bar","tooltip":true},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"BuildingName","type":"nominal","sort":{"order":"descending","encoding":"y"},"scale":{"type":"linear","zero":false}},"y":{"field":"MeanSGP","type":"nominal","sort":{"order":"ascending","encoding":"y"},"scale":{"type":"linear","zero":true}},"color":{"field":"ZIP_CODE","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %%
_deepnote_run_altair(df_test_eco_dis, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"point","tooltip":true},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"BuildingName","type":"nominal","sort":{"order":"ascending","encoding":"y"},"scale":{"type":"linear","zero":false}},"y":{"field":"ZIP_CODE","type":"nominal","sort":{"order":"descending","encoding":"y"},"scale":{"type":"linear","zero":false}},"color":{"field":"","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %%
# Finding which schools are magnet schools within the district

df_magnet_schools = df_test[df_test['BuildingName'].str.contains("Magnet")]
df_magnet_schools['BuildingName'].unique()
# Out:
# array(['Ann Arbor Trail Magnet School', 'Ludington Magnet Middle School',
#        'Fisher Magnet Lower Academy', 'Fisher Magnet Upper Academy'],
#       dtype=object)

# %%
_deepnote_run_altair(df_magnet_schools, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"bar","tooltip":true},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"BuildingName","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}},"y":{"field":"PercentAverageGrowth","type":"quantitative","sort":null,"scale":{"type":"linear","zero":true}},"color":{"field":"ZIP_CODE","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Descriptive Incites

# %% [markdown]
# Creating a data frame with quantitative data

# %%
#checking what kinds of values are in each column
df_test.dtypes
#Looking at the unique values in each column I want to chang to float

# df_test['NumberAboveAverageGrowth'].unique()
# df_test['NumberAverageGrowth'].unique()
# df_test['NumberBelowAverageGrowth'].unique()
# df_test['PercentAboveAverage'].unique()
# df_test['PercentAverageGrowth'].unique()
# df_test['PercentBelowAverage'].unique()
# df_test['TotalIncluded'].unique()
# df_test['MeanSGP'].unique()

df_test_int = df_test.copy()

#changing values with < or > to just the number in order to plot easier
df_test_int['NumberAboveAverageGrowth'] = df_test_int['NumberAboveAverageGrowth'].replace('< 10', 10)
df_test_int['NumberAverageGrowth'] = df_test_int['NumberAverageGrowth'].replace('< 10', 10)
df_test_int['NumberBelowAverageGrowth'] = df_test_int['NumberBelowAverageGrowth'].replace('< 10', 10)
df_test_int['PercentAboveAverage'] = df_test_int['PercentAboveAverage'].replace('< 10', 10)
df_test_int['PercentAboveAverage'] = df_test_int['PercentAboveAverage'].replace('< 5', 5)
df_test_int['PercentAverageGrowth'] = df_test_int['PercentAverageGrowth'].replace('< 10', 10)
df_test_int['PercentAverageGrowth'] = df_test_int['PercentAverageGrowth'].replace('< 5', 5)
df_test_int['PercentBelowAverage'] = df_test_int['PercentBelowAverage'].replace('< 10', 10)
df_test_int['PercentBelowAverage'] = df_test_int['PercentBelowAverage'].replace('< 5', 5)
df_test_int['TotalIncluded'] = df_test_int['TotalIncluded'].replace('< 10', 10)
df_test_int['MeanSGP'] = df_test_int['MeanSGP'].replace('< 10', 10)

# %% [markdown]
# normalizing the quantitative data

# %%
#normalizing all of the quantitative data because the number of individuals for different groups differ so much
col = ['NumberAboveAverageGrowth', 'NumberAverageGrowth', 'NumberBelowAverageGrowth', 'PercentAboveAverage', 'PercentAverageGrowth', 'PercentBelowAverage', 'TotalIncluded', 'MeanSGP' ]

#turning objects into floats
for col_name in col:
    df_test_int[col_name] =  df_test_int[col_name].astype(float)

new_cols = []
for col_name in col:
    x = np.array(df_test_int[col_name])
    norm = preprocessing.normalize([x])
    new_cols.append(norm)

# %%
new_df = df_test_int[['SchoolYear','BuildingName','CountyName', 'SchoolLevel',
       'Locale', 'Grade', 'Subject', 'TestingGroup', 'ISDCode', 'ISDName', 'Status', 'SCHOOL_EMPHASIS',
       'PhoneNumber', 'ADDRESS_LINE_1', 'CITY', 'STATE', 'ZIP_CODE']]

NumberAboveAverageGrowth = new_cols[0][0].tolist()
NumberAverageGrowth = new_cols[1][0].tolist()
NumberBelowAverageGrowth = new_cols[2][0].tolist()
PercentAboveAverage = new_cols[3][0].tolist()
PercentAverageGrowth = new_cols[4][0].tolist()
PercentBelowAverage = new_cols[5][0].tolist()
TotalIncluded =  new_cols[6][0].tolist()
MeanSGP = new_cols[7][0].tolist()

new_df['NumberAboveAverageGrowth'] = NumberAboveAverageGrowth
new_df['NumberAverageGrowth'] = NumberAverageGrowth
new_df['NumberBelowAverageGrowth'] = NumberBelowAverageGrowth
new_df['PercentAboveAverage'] = PercentAboveAverage
new_df['PercentAverageGrowth'] = PercentAverageGrowth
new_df['PercentBelowAverage'] = PercentBelowAverage
new_df['TotalIncluded'] = TotalIncluded
new_df['MeanSGP'] = MeanSGP
# Out:
# /tmp/ipykernel_1082/148430513.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['NumberAboveAverageGrowth'] = NumberAboveAverageGrowth
# /tmp/ipykernel_1082/148430513.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['NumberAverageGrowth'] = NumberAverageGrowth
# /tmp/ipykernel_1082/148430513.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['NumberBelowAverageGrowth'] = NumberBelowAverageGrowth
# /tmp/ipykernel_1082/148430513.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['PercentAboveAverage'] = PercentAboveAverage
# /tmp/ipykernel_1082/148430513.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['PercentAverageGrowth'] = PercentAverageGrowth
# /tmp/ipykernel_1082/148430513.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['PercentBelowAverage'] = PercentBelowAverage
# /tmp/ipykernel_1082/148430513.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['TotalIncluded'] = TotalIncluded
# /tmp/ipykernel_1082/148430513.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['MeanSGP'] = MeanSGP

# %%
#looking at the different types of groups in order to compare ones of interest
df_test_int['TestingGroup'].unique()
# Out:
# array(['Students with Disabilities', 'Students without Disabilities',
#        'All Students', 'Economically Disadvantaged',
#        'Not Economically Disadvantaged',
#        'American Indian or Alaska Native',
#        'Black, not of Hispanic origin', 'Male', 'Female',
#        'Not English Learners', 'Not Migrant',
#        'White, not of Hispanic origin', 'Two or More Races',
#        'English Learners', 'Hispanic', 'Asian',
#        'Native Hawaiian or Other Pacific Islander'], dtype=object)

# %%
df_percabove_disability = new_df.loc[((new_df['TestingGroup'] == 'Students with Disabilities') | (df_test_int['TestingGroup'] =='Students without Disabilities')) & (df_test_int['Grade'] == 'All Grades') & (df_test_int['Subject'] == 'Mathematics')]

# %%
alt.Chart(df_percabove_disability).mark_circle(size=60).encode(
    x='BuildingName',
    y='PercentAboveAverage',
    color='TestingGroup',
    tooltip=['BuildingName', 'PercentAboveAverage', 'TestingGroup']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Disabled Students

# %% [markdown]
# Comparing the avg.  number of students with disabilities above avg, below avg and at avg. per zip code

# %%
df_zip_dis = new_df.loc[(new_df['TestingGroup'] == 'Students with Disabilities') & (df_test_int['Grade'] == 'All Grades')]
# df_zip_dis['TestingGroup'].unique()
df_zip_dis = df_zip_dis.groupby(['ZIP_CODE']).mean()
df_zip_dis = df_zip_dis.reset_index()
df_zip_dis = df_zip_dis.sort_values('NumberAboveAverageGrowth', axis = 0, ascending = True)
df_zip_dis.head()
# Out:
#     ZIP_CODE  ISDCode   PhoneNumber  NumberAboveAverageGrowth  \
# 22     48234     82.0  3.138665e+09                  0.003726
# 11     48213     82.0  3.138624e+09                  0.003726
# 0      48201     82.0  3.134365e+09                  0.003726
# 23     48235     82.0  3.136135e+09                  0.003726
# 16     48219     82.0  3.135973e+09                  0.003726
#
#     NumberAverageGrowth  NumberBelowAverageGrowth  PercentAboveAverage  \
# 22             0.002699                  0.003273             0.005573
# 11             0.002993                  0.003057             0.006025
# 0              0.002672                  0.002727             0.004002
# 23             0.002721                  0.003049             0.005352
# 16             0.003073                  0.003864             0.004282
#
#     PercentAverageGrowth  PercentBelowAverage  TotalIncluded   MeanSGP
# 22              0.007358             0.007800       0.001853  0.006262
# 11              0.006392             0.008394       0.002020  0.006179
# 0               0.003931             0.004285       0.001239  0.003386
# 23              0.004566             0.006313       0.001580  0.004743
# 16              0.007218             0.008486       0.002280  0.005398

# %%
all_dis = alt.Chart(df_zip_dis).transform_fold(
    ['NumberAboveAverageGrowth', 'NumberAverageGrowth', 'NumberBelowAverageGrowth'],
).mark_bar().encode(
    x='ZIP_CODE:N',
    y='value:Q',
    color='key:N',
    tooltip = ['ZIP_CODE','NumberAboveAverageGrowth', 'NumberAverageGrowth', 'NumberBelowAverageGrowth']
).interactive(
).properties(
        title = 'Average Number Above, At and Below Average Growth For Disabled Students per Zip Code'
)
all_dis
# Out:
# alt.Chart(...)

# %% [markdown]
# Comparing the percent above, at and below average for disabled students per zip code.

# %%
Perc_dis = alt.Chart(df_zip_dis).transform_fold(
    ['PercentAboveAverage', 'PercentAverageGrowth', 'PercentBelowAverage'],
).mark_bar().encode(
    x='ZIP_CODE:N',
    y='value:Q',
    color='key:N',
    tooltip = ['ZIP_CODE','PercentAboveAverage', 'PercentAverageGrowth', 'PercentBelowAverage']
).interactive(
).properties(
        title = 'Average Percent Above, At and Below Average Growth For Disabled Students per Zip Code'
)
Perc_dis
# Out:
# alt.Chart(...)

# %%
#creating dataframe with diabled and abled indivudials to compare
df_zip_dis_nondis = new_df.loc[((new_df['TestingGroup'] == 'Students with Disabilities') | (df_test_int['TestingGroup'] == 'Students without Disabilities')) & (df_test_int['Grade'] == 'All Grades')]
# df_zip_dis['TestingGroup'].unique()
df_zip_dis_nondis = df_zip_dis_nondis.groupby(['ZIP_CODE', 'TestingGroup']).mean()
df_zip_dis_nondis = df_zip_dis_nondis.reset_index()
#df_zip_dis_nondis = df_zip_dis_nondis.sort_values('NumberAboveAverageGrowth', axis = 0, ascending = True)
df_zip_dis_nondis.head()
# Out:
#    ZIP_CODE                   TestingGroup  ISDCode   PhoneNumber  \
# 0     48201     Students with Disabilities     82.0  3.134365e+09
# 1     48201  Students without Disabilities     82.0  3.134365e+09
# 2     48202     Students with Disabilities     82.0  3.136838e+09
# 3     48202  Students without Disabilities     82.0  3.136838e+09
# 4     48203     Students with Disabilities     82.0  3.138665e+09
#
#    NumberAboveAverageGrowth  NumberAverageGrowth  NumberBelowAverageGrowth  \
# 0                  0.003726             0.002672                  0.002727
# 1                  0.015400             0.019572                  0.019115
# 2                  0.003726             0.002717                  0.002840
# 3                  0.008259             0.007348                  0.006672
# 4                  0.003726             0.002672                  0.002937
#
#    PercentAboveAverage  PercentAverageGrowth  PercentBelowAverage  \
# 0             0.004002              0.003931             0.004285
# 1             0.007117              0.010638             0.010873
# 2             0.006304              0.007248             0.008596
# 3             0.011743              0.009631             0.008639
# 4             0.007662              0.007701             0.008095
#
#    TotalIncluded   MeanSGP
# 0       0.001239  0.003386
# 1       0.019330  0.009481
# 2       0.001797  0.007097
# 3       0.007362  0.011453
# 4       0.001794  0.007976

# %%
#Chart showing the difference between students with and without disabilities who were above average
zip_dis_nondis_numabove = alt.Chart(df_zip_dis_nondis).mark_bar().encode(
    alt.X('ZIP_CODE:N', sort=alt.EncodingSortField(field="ZIP_CODE", op="count", order='ascending')),
    y=alt.Y('PercentAboveAverage:Q'),
    color = 'TestingGroup:N',
    tooltip=['ZIP_CODE', 'TestingGroup','PercentAboveAverage']
).interactive(
).properties(
        title = 'Average Percent of Disabled vs. Non-disabled Students Above Average Growth per Zip Code'
)

zip_dis_nondis_numabove
# Out:
# alt.Chart(...)

# %%
#Chart showing the difference between students with and without disabilities who were above average
perc_above_avg_dis = alt.Chart(df_zip_dis_nondis).mark_bar().encode(
    x=alt.X('TestingGroup:N', title = None),
    y='PercentAboveAverage:Q',
    color='TestingGroup:N',
    column='ZIP_CODE:N'
)
perc_above_avg_dis
# Out:
# alt.Chart(...)

# %%
#Chart showing the difference between students with and without disabilities who were at average
zip_dis_nondis_numat = alt.Chart(df_zip_dis_nondis).mark_bar().encode(
    alt.X('ZIP_CODE:N', sort=alt.EncodingSortField(field="ZIP_CODE", op="count", order='ascending')),
    y=alt.Y('PercentAverageGrowth:Q'),
    color = 'TestingGroup:N',
    tooltip=['ZIP_CODE', 'TestingGroup','PercentAverageGrowth']
).interactive(
).properties(
        title = 'Average Percent of Disabled vs. Non-disabled Students At Average Growth per Zip Code'
)

zip_dis_nondis_numat
# Out:
# alt.Chart(...)

# %%
#Chart showing the difference between students with and without disabilities who were at average
perc_at_avg_dis = alt.Chart(df_zip_dis_nondis).mark_bar().encode(
    x=alt.X('TestingGroup:N', title = None),
    y='PercentAverageGrowth:Q',
    color='TestingGroup:N',
    column='ZIP_CODE:N'
)

perc_at_avg_dis
# Out:
# alt.Chart(...)

# %%
#Chart showing the difference between students with and without disabilities who were below average
zip_dis_nondis_numat = alt.Chart(df_zip_dis_nondis).mark_bar().encode(
    alt.X('ZIP_CODE:N', sort=alt.EncodingSortField(field="ZIP_CODE", op="count", order='ascending')),
    y=alt.Y('PercentBelowAverage:Q'),
    color = 'TestingGroup:N',
    tooltip=['ZIP_CODE', 'TestingGroup','PercentBelowAverage']
).interactive(
).properties(
        title = 'Average Percent of Disabled vs. Non-disabled Students Below Average Growth per Zip Code'
)

zip_dis_nondis_numat
# Out:
# alt.Chart(...)

# %%
#Chart showing the difference between students with and without disabilities who were below average
perc_below_avg_dis = alt.Chart(df_zip_dis_nondis).mark_bar().encode(
    x=alt.X('TestingGroup:N', title = None),
    y='PercentBelowAverage:Q',
    color='TestingGroup:N',
    column='ZIP_CODE:N'
)
perc_below_avg_dis
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Economically Disadvantaged

# %% [markdown]
# Comparing the avg.  number of students with disabilities above avg, below avg and at avg. per zip code

# %%
df_zip_ecodis = new_df.loc[(new_df['TestingGroup'] == 'Economically Disadvantaged') & (df_test_int['Grade'] == 'All Grades')]
df_zip_ecodis = df_zip_ecodis.groupby(['ZIP_CODE']).mean()
df_zip_ecodis = df_zip_ecodis.reset_index()
df_zip_ecodis = df_zip_ecodis.sort_values('NumberAboveAverageGrowth', axis = 0, ascending = True)
df_zip_ecodis.head()
# Out:
#     ZIP_CODE  ISDCode   PhoneNumber  NumberAboveAverageGrowth  \
# 26     48239     82.0  3.132749e+09                  0.005216
# 15     48217     82.0  3.133866e+09                  0.005837
# 12     48214     82.0  3.138616e+09                  0.007517
# 22     48234     82.0  3.138665e+09                  0.007638
# 1      48202     82.0  3.136838e+09                  0.008135
#
#     NumberAverageGrowth  NumberBelowAverageGrowth  PercentAboveAverage  \
# 26             0.006947                  0.011271             0.006379
# 15             0.004631                  0.005139             0.009693
# 12             0.006947                  0.006571             0.007832
# 22             0.008470                  0.011117             0.006025
# 1              0.007838                  0.006853             0.010341
#
#     PercentAverageGrowth  PercentBelowAverage  TotalIncluded   MeanSGP
# 26              0.009737             0.012229       0.007990  0.008479
# 15              0.008169             0.011390       0.004815  0.010039
# 12              0.009840             0.009082       0.006705  0.009356
# 22              0.009363             0.011017       0.009274  0.007977
# 1               0.010136             0.009127       0.007763  0.010958

# %%
all_ecodis = alt.Chart(df_zip_ecodis).transform_fold(
    ['NumberAboveAverageGrowth', 'NumberAverageGrowth', 'NumberBelowAverageGrowth'],
).mark_bar().encode(
    x='ZIP_CODE:N',
    y='value:Q',
    color='key:N',
    tooltip = ['ZIP_CODE','NumberAboveAverageGrowth', 'NumberAverageGrowth', 'NumberBelowAverageGrowth']
).interactive(
).properties(
        title = 'Average Number Above, At and Below Average Growth For Economically Disadvantage Students per Zip Code'
)
all_ecodis
# Out:
# alt.Chart(...)

# %%
perc_ecodis = alt.Chart(df_zip_ecodis).transform_fold(
    ['PercentAboveAverage', 'PercentAverageGrowth', 'PercentBelowAverage'],
).mark_bar().encode(
    x='ZIP_CODE:N',
    y='value:Q',
    color='key:N',
    tooltip = ['ZIP_CODE','PercentAboveAverage', 'PercentAverageGrowth', 'PercentBelowAverage']
).interactive(
).properties(
        title = 'Average Percent Above, At and Below Average Growth For Economically Disadvantages Students per Zip Code'
)
perc_ecodis
# Out:
# alt.Chart(...)

# %%
#creating dataframe with diabled and abled indivudials to compare
df_zip_ecodis_not = new_df.loc[((new_df['TestingGroup'] == 'Economically Disadvantaged') | (df_test_int['TestingGroup'] == 'Not Economically Disadvantaged')) & (df_test_int['Grade'] == 'All Grades')]
# df_zip_dis['TestingGroup'].unique()
df_zip_ecodis_not = df_zip_ecodis_not.groupby(['ZIP_CODE', 'TestingGroup']).mean()
df_zip_ecodis_not = df_zip_ecodis_not.reset_index()
#df_zip_dis_nondis = df_zip_dis_nondis.sort_values('NumberAboveAverageGrowth', axis = 0, ascending = True)
df_zip_ecodis_not.head()
# Out:
#    ZIP_CODE                    TestingGroup  ISDCode   PhoneNumber  \
# 0     48201      Economically Disadvantaged     82.0  3.134365e+09
# 1     48201  Not Economically Disadvantaged     82.0  3.134365e+09
# 2     48202      Economically Disadvantaged     82.0  3.136838e+09
# 3     48202  Not Economically Disadvantaged     82.0  3.136838e+09
# 4     48203      Economically Disadvantaged     82.0  3.138665e+09
#
#    NumberAboveAverageGrowth  NumberAverageGrowth  NumberBelowAverageGrowth  \
# 0                  0.012574             0.016032                  0.015734
# 1                  0.005309             0.005121                  0.004959
# 2                  0.008135             0.007838                  0.006853
# 3                  0.003726             0.002672                  0.002705
# 4                  0.011443             0.009466                  0.010163
#
#    PercentAboveAverage  PercentAverageGrowth  PercentBelowAverage  \
# 0             0.007120              0.010592             0.010916
# 1             0.006388              0.008428             0.007437
# 2             0.010341              0.010136             0.009127
# 3             0.008030              0.005474             0.009281
# 4             0.010861              0.008016             0.008179
#
#    TotalIncluded   MeanSGP
# 0       0.015823  0.009491
# 1       0.004361  0.007530
# 2       0.007763  0.010958
# 3       0.001518  0.006889
# 4       0.010452  0.010174

# %%
#Chart showing the difference between students with and without disabilities who were above average
df_zip_ecodis_not_above = alt.Chart(df_zip_ecodis_not).mark_bar().encode(
    alt.X('ZIP_CODE:N', sort=alt.EncodingSortField(field="ZIP_CODE", op="count", order='ascending')),
    y=alt.Y('PercentAboveAverage:Q'),
    color = 'TestingGroup:N',
    tooltip=['ZIP_CODE', 'TestingGroup','PercentAboveAverage']
).interactive(
).properties(
        title = 'Average Percent of Non vs. Economically Disadvantaged Students Above Average Growth per Zip Code'
)

df_zip_ecodis_not_above
# Out:
# alt.Chart(...)

# %%
#Chart showing the difference between students with and without disabilities who were above average
perc_above_avg_eco = alt.Chart(df_zip_ecodis_not).mark_bar().encode(
    x=alt.X('TestingGroup:N', title = None),
    y='PercentAboveAverage:Q',
    color='TestingGroup:N',
    column='ZIP_CODE:N'
)
perc_above_avg_eco
# Out:
# alt.Chart(...)

# %% [markdown]
# ***Can continue with these visualizations as was done with disabled vs. non-disabled

# %% [markdown]
# ## Comparing between Certain TestingGroups

# %%
#creating a dataframe to compare testing groups
df_compare_some = new_df.loc[((new_df['TestingGroup'] == 'Students with Disabilities') | (new_df['TestingGroup'] == 'Students without Disabilities') | (new_df['TestingGroup'] == 'Economically Disadvantaged') |
   (new_df['TestingGroup'] == 'Not Economically Disadvantaged') | (new_df['TestingGroup'] == 'Male') | (new_df['TestingGroup'] == 'Female')) & (df_test_int['Grade'] == 'All Grades')]
df_compare_some = df_compare_some.groupby(['ZIP_CODE', 'TestingGroup']).mean()
df_compare_some = df_compare_some.reset_index()
df_compare_some = df_compare_some.sort_values('NumberAboveAverageGrowth', axis = 0, ascending = True)
# df_compare_some.head()

# %%
#creating a dataframe to compare the percent growth of the top 4 most common races in america
american_races_4 = new_df.loc[((new_df['TestingGroup'] == 'Black, not of Hispanic origin') | (new_df['TestingGroup'] == 'Asian') | (new_df['TestingGroup'] == 'White, not of Hispanic origin') | (new_df['TestingGroup'] == 'Hispanic')) & (df_test_int['Grade'] == 'All Grades')]
american_races_4 = american_races_4.groupby(['ZIP_CODE', 'TestingGroup']).mean()
american_races_4 = american_races_4.reset_index()
american_races_4 = american_races_4.sort_values('NumberAboveAverageGrowth', axis = 0, ascending = True)
# american_races_4.head()

# %%
bars = alt.Chart().mark_bar(size = 8).encode(
    x=alt.X('PercentAverageGrowth:Q', stack='zero'),
    y=alt.Y('ZIP_CODE:N'),
    color=alt.Color('TestingGroup')
).properties(
    width = 100,
    height = 300
    # title = 'Percent Avg. Growth in each Zip Code for TestingGroups',
)

text = alt.Chart().mark_text(dx=-17, dy=2, color='white').encode(
    x=alt.X('PercentAverageGrowth:Q', stack='zero'),
    y=alt.Y('ZIP_CODE:N'),
    detail='TestingGroup:N',
    text=alt.Text('PercentAverageGrowth:Q', format='.3f')
)

alt.layer(bars, text, data=df_compare_some).facet(column='TestingGroup:N')
# Out:
# alt.FacetChart(...)

# %%
bars1 = alt.Chart(american_races_4).mark_bar().encode(
    x=alt.X('PercentAverageGrowth:Q', stack='zero'),
    y=alt.Y('ZIP_CODE:N'),
    color=alt.Color('TestingGroup')
).properties(
    width = 100,
    height = 300
)

text1 = alt.Chart(american_races_4).mark_text(dx= -15, dy= 2, color='white').encode(
    x=alt.X('PercentAverageGrowth:Q', stack='zero'),
    y=alt.Y('ZIP_CODE:N'),
    detail='TestingGroup:N',
    text=alt.Text('PercentAverageGrowth:Q', format='.3f')
)


alt.layer(bars1, text1, data=american_races_4).facet(column='TestingGroup:N')
# Out:
# alt.FacetChart(...)

# %% [markdown]
# There is not enough data to be able to accurately compare between races for percent average growth per zip code

# %% [markdown]
# ## Comparing Different School Types

# %% [markdown]
# application, magnet, regular

# %%
#creating a sub dataframe to compare between school types
testing_this = new_df.loc[(df_test_int['Grade'] == 'All Grades') & (df_test_int['TestingGroup'] == 'All Students') ]
# testing_this.SCHOOL_EMPHASIS.value_counts()
# # testing_this.shape
# # testing_this
# Out:
# General Education        283
# Alternative Education      6
# Special Education          4
# Name: SCHOOL_EMPHASIS, dtype: int64

# %%
app_schools = ['Academy of The Americas', 'Bates Academy', 'Benjamin Carson High School of Science and Medicine', 'Clippert Academy',
    'Chrysler Elementary School', 'Detroit International Academy', 'Detroit School of Arts',
    'Foreign Language Immersion and Cultural Studies', 'Golightly Education CenterGolightly Education Center',
    'Garvey Academy', 'Paul Robeson Malcolm X Academy', 'The School at Marygrove',
    'Academy of The Americas High School', 'Benjamin Carson High School of Science and Medicine',
    'Davis Aerospace Technical High School at Golightly', 'Detroit International Academy for Young Women',
    'Detroit School of Arts', 'Frederick Douglass Academy for Young Men', 'Brenda Scott Academy for Theatre Arts', 'Edison Elementary School', 'Palmer Park Preparatory Academy',
    'John R. King Academic and Performing Arts Academy', 'Spain Elementary-Middle School']

mag_schools = ['Ann Arbor Trail Magnet School', 'Ludington Magnet Middle School',
    'Fisher Magnet Lower Academy', 'Fisher Magnet Upper Academy']


#getting a list of all the schools that were not included in the magnet or application list
building = list(testing_this.BuildingName)
main_list = list(set(building) - set(app_schools))
reg_schools = list(set(main_list) - set(mag_schools))
reg_schools.sort()
# reg_schools

# %%
#changing the school emphasis to match the results from the list we found on the DPSCD website

testing_this.loc[new_df.BuildingName.isin(app_schools), 'SCHOOL_EMPHASIS'] = 'applied'
testing_this.loc[new_df.BuildingName.isin(mag_schools), 'SCHOOL_EMPHASIS'] = 'magnet'
testing_this.loc[new_df.BuildingName.isin(reg_schools), 'SCHOOL_EMPHASIS'] = 'regular'

testing_this.groupby('SCHOOL_EMPHASIS').sum()
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                  ISDCode   PhoneNumber  ZIP_CODE  NumberAboveAverageGrowth  \
# SCHOOL_EMPHASIS
# applied             4428  169369338922   2603537                  0.896416
# magnet              1066   40765554516    626823                  0.144559
# regular            18532  708944085596  10897178                  3.112494
#
#                  NumberAverageGrowth  NumberBelowAverageGrowth  \
# SCHOOL_EMPHASIS
# applied                     0.871062                  0.798771
# magnet                      0.205207                  0.254806
# regular                     3.327671                  3.406340
#
#                  PercentAboveAverage  PercentAverageGrowth  \
# SCHOOL_EMPHASIS
# applied                     0.460749              0.562591
# magnet                      0.082977              0.118080
# regular                     1.795565              2.101917
#
#                  PercentBelowAverage  TotalIncluded   MeanSGP
# SCHOOL_EMPHASIS
# applied                     0.509392       0.891181  0.539692
# magnet                      0.130735       0.213741  0.103930
# regular                     2.131512       3.402376  2.064543

# %%
#creating a data frame to compare all grades for each zipcode
df_emph = testing_this.loc[(testing_this['Grade'] == 'All Grades')]
df_emph = df_emph.groupby(['ZIP_CODE','BuildingName', 'SCHOOL_EMPHASIS']).mean()
df_emph = df_emph.reset_index()
df_emph['counting'] = 1
df_emph = df_emph.groupby(['ZIP_CODE','SCHOOL_EMPHASIS']).sum()
df_emph = df_emph.reset_index()

# df_emph

# %%
#showing the count of each type of school for each zip code 
alt.Chart(df_emph).mark_bar().encode(
    x=alt.X('ZIP_CODE:N', title = None),
    y='counting:Q',
    color = 'SCHOOL_EMPHASIS',
    tooltip = ['SCHOOL_EMPHASIS', 'counting']
).interactive()
# Out:
# alt.Chart(...)

# %%
emphasis = testing_this.loc[(df_test_int['Grade'] == 'All Grades')]
emphasis = emphasis.groupby(['ZIP_CODE', 'SCHOOL_EMPHASIS']).sum()
emphasis = emphasis.reset_index()
# emphasis = emphasis.sort_values('NumberAboveAverageGrowth', axis = 0, ascending = True)

# %%
#seeing which zip codes contain certain types of schools and if there is a 
#noticable difference in percent growth between the school types for precent growth

# perc_above_avg_eco = alt.Chart(emphasis).mark_bar().encode(
#     x=alt.X('SCHOOL_EMPHASIS:N', title = None),
#     y='PercentAboveAverage:Q',
#     color='SCHOOL_EMPHASIS:N',
#     column='ZIP_CODE:N'
# )

perc_at_avg_eco = alt.Chart(emphasis).mark_bar().encode(
    x=alt.X('SCHOOL_EMPHASIS:N', title = None),
    y='PercentAverageGrowth:Q',
    color='SCHOOL_EMPHASIS:N',
      column='ZIP_CODE:N'
)

# perc_below_avg_eco = alt.Chart(emphasis).mark_bar().encode(
#     x=alt.X('SCHOOL_EMPHASIS:N', title = None),
#     y='PercentBelowAverage:Q',
#     color='SCHOOL_EMPHASIS:N',
#     column='ZIP_CODE:N'
# )
perc_at_avg_eco


#No patterns stood out for percent growth between schools
# Out:
# alt.Chart(...)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e115903d-6f9d-4ba6-a598-8111e36ee3b2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
